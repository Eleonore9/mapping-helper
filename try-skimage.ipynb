# %% [markdown]
# ## try out Sci-kit image

# %%
from skimage import data, io, filters

# %%
houses = io.imread("sample-images/houses-kipushi-drc.png")

io.imshow(houses)

# %%
print houses[0]
# Out:
# [[ 96  97 101]
#  [ 96  97 101]
#  [ 96  95 100]
#  ...,
#  [114 108 110]
#  [115 109 111]
#  [115 109 111]]

# %%
nb_houses = io.imread("sample-images/nb-houses-kipushi-drc.png")

io.imshow(nb_houses)

# %%
print nb_houses[0]
# Out:
# [ 97  97  96  96  96  96  87  87  89  89  93  93  93  95  95  95  95  95
#   95  94  94  94  94  97  97  99  99 103 103 103 105 105 101 101  98  98
#  101 101 106 106 110 110 107 107 109 109 105 105 105 101 101 100 100  99
#   99 105 105 103 103  99  99 100 100 105 105 105 108 108 106 106 103 103
#  103 103 105 105 101 101  99  99 101 101 101 101 101  97  97  89  89  83
#   83  87  87  93  93  98  98  94  94  94  90  90  96  96 104 104 104 104
#   97  97  95  95  88  88  94  94 101 101 101 107 107 120 120 124 124 125
#  125 124 124 124 124 126 126 128 128 128 128 128 126 126 123 123 123 123
#  121 121 119 119 119 119 120 120 122 122 122 126 126 131 131 134 134 135
#  135 138 138 139 139 137 137 132 132 132 129 129 129 129 130 130 132 132
#  136 136 138 138 137 137 135 135 133 133 133 132 132 135 135 131 131 131
#  131 132 132 132 132 130 130 128 128 128 128 128 132 132 137 137 142 142
#  138 138 125 125 106 106  88  88  77  77  77  79  79  93  93 106 106 108
# ...

# %%
edges_houses = filters.sobel(nb_houses)
io.imshow(edges_houses)

# %%
nbc_houses = io.imread("sample-images/nbc-houses-kipushi-drc.png")

io.imshow(nbc_houses)

# %%
edges_houses2 = filters.sobel(nbc_houses)
io.imshow(edges_houses2)
